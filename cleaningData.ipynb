# %%
import pandas as pd

# %%
df = pd.read_csv('csvs/paso_a_paso.csv')

# %%
df
# Out:
#      codigo_region   region_residencia  codigo_comuna comuna_residencia  \
# 0               15  Arica y Parinacota          15101             Arica
# 1               15  Arica y Parinacota          15101             Arica
# 2               15  Arica y Parinacota          15102         Camarones
# 3               15  Arica y Parinacota          15202     General Lagos
# 4               15  Arica y Parinacota          15201             Putre
# ..             ...                 ...            ...               ...
# 380             12          Magallanes          12101      Punta Arenas
# 381             12          Magallanes          12103         Río Verde
# 382             12          Magallanes          12104      San Gregorio
# 383             12          Magallanes          12303          Timaukel
# 384             12          Magallanes          12402  Torres del Paine
#
#        zona  2020-07-28  2020-07-29  2020-07-30  2020-07-31  2020-08-01  ...  \
# ...

# %%
santiago = df.loc[df['codigo_region'] == 13]

# %%
region_comuna_fase = df[['codigo_region','region_residencia','codigo_comuna','comuna_residencia','zona','2021-06-29']]

# %%
region_comuna_fase
# Out:
#      codigo_region   region_residencia  codigo_comuna comuna_residencia  \
# 0               15  Arica y Parinacota          15101             Arica
# 1               15  Arica y Parinacota          15101             Arica
# 2               15  Arica y Parinacota          15102         Camarones
# 3               15  Arica y Parinacota          15202     General Lagos
# 4               15  Arica y Parinacota          15201             Putre
# ..             ...                 ...            ...               ...
# 380             12          Magallanes          12101      Punta Arenas
# 381             12          Magallanes          12103         Río Verde
# 382             12          Magallanes          12104      San Gregorio
# 383             12          Magallanes          12303          Timaukel
# 384             12          Magallanes          12402  Torres del Paine
#
#        zona  2021-06-29
# 0     Rural           2
# 1    Urbana           2
# 2     Total           4
# ...

# %%
region_comuna_fase[['codigo_region','region_residencia']]
# Out:
#      codigo_region   region_residencia
# 0               15  Arica y Parinacota
# 1               15  Arica y Parinacota
# 2               15  Arica y Parinacota
# 3               15  Arica y Parinacota
# 4               15  Arica y Parinacota
# ..             ...                 ...
# 380             12          Magallanes
# 381             12          Magallanes
# 382             12          Magallanes
# 383             12          Magallanes
# 384             12          Magallanes
#
# [385 rows x 2 columns]

# %%
santiago = santiago[['codigo_comuna','comuna_residencia' ,'codigo_region','region_residencia','2021-06-29']]

# %%
santiago = santiago[['codigo_comuna', 'comuna_residencia', '2021-06-29']]

# %%
santiago['Fase Comuna'] = santiago['2021-06-29']

# %%
santiago = santiago.drop(columns=['2021-06-29'])

# %%
santiago
# Out:
#      codigo_comuna    comuna_residencia  codigo_region region_residencia  \
# 87           13502                Alhué             13     Metropolitana
# 88           13402                 Buin             13     Metropolitana
# 89           13403      Calera de Tango             13     Metropolitana
# 90           13102            Cerrillos             13     Metropolitana
# 91           13103          Cerro Navia             13     Metropolitana
# 92           13301               Colina             13     Metropolitana
# 93           13104             Conchalí             13     Metropolitana
# 94           13503             Curacaví             13     Metropolitana
# 95           13503             Curacaví             13     Metropolitana
# 96           13105            El Bosque             13     Metropolitana
# 97           13602             El Monte             13     Metropolitana
# 98           13106     Estación Central             13     Metropolitana
# ...

# %%
compression_opts = dict(method='zip',

                        archive_name='csvs/regiones.csv')  

regiones.to_csv('regiones.zip', index=False,

          compression=compression_opts)

# %%
df
# Out:
#      codigo_region   region_residencia  codigo_comuna comuna_residencia  \
# 0               15  Arica y Parinacota          15101             Arica
# 1               15  Arica y Parinacota          15101             Arica
# 2               15  Arica y Parinacota          15102         Camarones
# 3               15  Arica y Parinacota          15202     General Lagos
# 4               15  Arica y Parinacota          15201             Putre
# ..             ...                 ...            ...               ...
# 380             12          Magallanes          12101      Punta Arenas
# 381             12          Magallanes          12103         Río Verde
# 382             12          Magallanes          12104      San Gregorio
# 383             12          Magallanes          12303          Timaukel
# 384             12          Magallanes          12402  Torres del Paine
#
#        zona  2020-07-28  2020-07-29  2020-07-30  2020-07-31  2020-08-01  ...  \
# ...

# %%
df[['codigo_comuna','comuna_residencia' ,'codigo_region','region_residencia','2021-06-29']]
# Out:
#      codigo_comuna comuna_residencia  codigo_region   region_residencia  \
# 0            15101             Arica             15  Arica y Parinacota
# 1            15101             Arica             15  Arica y Parinacota
# 2            15102         Camarones             15  Arica y Parinacota
# 3            15202     General Lagos             15  Arica y Parinacota
# 4            15201             Putre             15  Arica y Parinacota
# ..             ...               ...            ...                 ...
# 380          12101      Punta Arenas             12          Magallanes
# 381          12103         Río Verde             12          Magallanes
# 382          12104      San Gregorio             12          Magallanes
# 383          12303          Timaukel             12          Magallanes
# 384          12402  Torres del Paine             12          Magallanes
#
#      2021-06-29
# 0             2
# 1             2
# 2             4
# 3             4
# ...

# %%
df = df[['codigo_comuna','comuna_residencia' ,'codigo_region','region_residencia','2021-06-29']]

# %%
regiones = df[['codigo_region', 'region_residencia']]

# %%
regiones = regiones.drop_duplicates()

# %%
# Out:
#      codigo_region   region_residencia
# 0               15  Arica y Parinacota
# 1               15  Arica y Parinacota
# 2               15  Arica y Parinacota
# 3               15  Arica y Parinacota
# 4               15  Arica y Parinacota
# ..             ...                 ...
# 380             12          Magallanes
# 381             12          Magallanes
# 382             12          Magallanes
# 383             12          Magallanes
# 384             12          Magallanes
#
# [385 rows x 2 columns]

# %%
regiones = regiones.sort_values(by=['codigo_region'])

# %%
regiones
# Out:
#      codigo_region   region_residencia
# 5                1            Tarapacá
# 13               2         Antofagasta
# 25               3             Atacama
# 34               4            Coquimbo
# 49               5          Valparaíso
# 142              6           O’Higgins
# 175              7               Maule
# 232              8              Biobío
# 267              9           Araucanía
# 315             10           Los Lagos
# 353             11               Aysén
# 373             12          Magallanes
# 87              13       Metropolitana
# 302             14            Los Ríos
# 0               15  Arica y Parinacota
# 209             16               Ñuble

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      codigo_comuna comuna_residencia  codigo_region   region_residencia  \
# 0            15101             Arica             15  Arica y Parinacota
# 2            15102         Camarones             15  Arica y Parinacota
# 3            15202     General Lagos             15  Arica y Parinacota
# 4            15201             Putre             15  Arica y Parinacota
# 5             1107     Alto Hospicio              1            Tarapacá
# ..             ...               ...            ...                 ...
# 380          12101      Punta Arenas             12          Magallanes
# 381          12103         Río Verde             12          Magallanes
# 382          12104      San Gregorio             12          Magallanes
# 383          12303          Timaukel             12          Magallanes
# 384          12402  Torres del Paine             12          Magallanes
#
#      2021-06-29
# 0             2
# 2             4
# 3             4
# 4             3
# ...

# %%
comunas = comunas.drop(columns= ['2021-06-29'])

# %%
comunas['Fase Comuna'] = comunas['2021-06-29']

# %%
comunas
# Out:
#      codigo_comuna comuna_residencia  codigo_region   region_residencia  \
# 0            15101             Arica             15  Arica y Parinacota
# 2            15102         Camarones             15  Arica y Parinacota
# 3            15202     General Lagos             15  Arica y Parinacota
# 4            15201             Putre             15  Arica y Parinacota
# 5             1107     Alto Hospicio              1            Tarapacá
# ..             ...               ...            ...                 ...
# 380          12101      Punta Arenas             12          Magallanes
# 381          12103         Río Verde             12          Magallanes
# 382          12104      San Gregorio             12          Magallanes
# 383          12303          Timaukel             12          Magallanes
# 384          12402  Torres del Paine             12          Magallanes
#
#      Fase Comuna
# 0              2
# 2              4
# 3              4
# 4              3
# ...
